# %%
# import libraries
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.signal as signal
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.tools import FigureFactory as FF
import scipy
import peakutils

# %%
foilCountDirectory="count_room_data/experiment/"
files = glob.glob(foilCountDirectory+'/*.Spe')

# %%
# Init a dict
dictFoilCount = {}

# Loop through files, create pandas panda frame
for file in files:
    name = file.split('_')[1]
    df = pd.read_table(file)
    data  = np.array(df['$SPEC_ID:'][11:16395], dtype='float')
    dictFoilCount[name] = data
keysFoilCount = list(dictFoilCount.keys())
# Out:
# ['count_room_data/experiment/20cm_liquid_Eu.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_040.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_041.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_043.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_042.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_046.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_047.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_045.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_044.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_021.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_009.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_023.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_037.Spe',
#  'count_room_data/experiment/225Ac_separated_10cm_005.Spe',
#  'count_room_data/experiment/225Ac_separated_10cm_004.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_036.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_022.Spe',
#  'count_room_data/experiment/Ra_alpha.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_008.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_020.Spe',
#  'count_room_data/experiment/Used_column_20cm.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_022.Spe',
#  'count_room_data/experiment/Rinse_water_20cm.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_008.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_034.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_020.Spe',
#  'count_room_data/experiment/225Ac_separated_10cm_006.Spe',
#  'count_room_data/experiment/225Ac_separated_10cm_007.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_021.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_035.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_009.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_023.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_031.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_025.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_019.Spe',
#  'count_room_data/experiment/225Ac_separated_10cm_003.Spe',
#  'count_room_data/experiment/225Ac_separated_10cm_002.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_018.Spe',
#  'count_room_data/experiment/Ra full spec.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_024.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_030.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_026.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_018.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_024.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_026.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_032.Spe',
#  'count_room_data/experiment/225Ac_separated_10cm_000.Spe',
#  'count_room_data/experiment/dogbones_80cm.Spe',
#  'count_room_data/experiment/225Ac_separated_10cm_001.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_033.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_027.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_025.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_019.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_014.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_000.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_002.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_016.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_017.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_003.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_001.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_015.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_003.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_017.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_029.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_015.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_001.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_000.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_014.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_028.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_016.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_002.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_006.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_012.Spe',
#  'count_room_data/experiment/225Ac_separated_50cm.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_010.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_004.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_038.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_039.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_005.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_011.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_013.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_007.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_011.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_005.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_007.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_013.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_012.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_006.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_004.Spe',
#  'count_room_data/experiment/225Ac_separated_8cm_010.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_049.Spe',
#  'count_room_data/experiment/225Ac_separated_20cm_048.Spe',
#  'count_room_data/experiment/50cm_liquid_Eu.Spe']

# %%
#cell energy calibration
def chan2E(channel):
        b0=-.07173963760775197
        b1=.18743348208034852
        E=b0+b1*channel
        return E

# %%
#cell energy decalibration
def E2chan(E):
        b0=-.07173963760775197
        b1=.18743348208034852
        channel=(E-b0)/b1
        return channel

# %%
# plt.subplots(6,3)
plt.figure(figsize=(20,20))
i = 1
for name in keysFoilCount:
    plt.subplot(6,3,i)
    chan = np.linspace(1,len(dictFoilCount[name]), len(dictFoilCount[name]))
    plt.semilogy(chan2E(chan), dictFoilCount[name])
    plt.plot()
    plt.title(name)
    i = i+1
plt.tight_layout()

# %%
left_endpt=14600
right_endpt=14800
plt.figure(figsize=(20,20))
i = 1
for name in keysFoilCount:
    plt.subplot(6,3,i)
    chan = np.linspace(left_endpt, right_endpt, right_endpt-left_endpt)
    plt.semilogy(chan2E(chan), dictFoilCount[name][left_endpt:right_endpt])
    plt.plot()
    plt.title(name)
    i = i+1
plt.tight_layout()

# %%
plt.figure(figsize=(20,20))
dictMaxGamma={}
dictMaxChannel={}
i = 1
for name in keysFoilCount:
    maxGamma=dictFoilCount[name][left_endpt]
    maxChannel=0
    j=[i for i in range(left_endpt,right_endpt)]
    for j in range(left_endpt,right_endpt):
        if dictFoilCount[name][j]>maxGamma:
            maxGamma=int(dictFoilCount[name][j])
            maxChannel=j
    dictMaxGamma[name]=maxGamma
    dictMaxChannel[name]=maxChannel
    i+=1
for name in keysFoilCount:
    print (name, dictMaxGamma[name], dictMaxChannel[name])

# %%
x = data[:,2]
y = data[:,3]
mean = sum(x*y)
sigma = sum(y*(x - mean)**2)

def gauss_function(x, a, x0, sigma):
    return a*np.exp(-(x-x0)**2/(2*sigma**2))
popt, pcov = curve_fit(gauss_function, x, y, p0 = [1, mean, sigma])
plt.plot(x, gauss_function(x, *popt), label='fit')

# plot data

plt.plot(x, y,'b')

# Add some axis labels

plt.legend()
plt.title('Fig. 3 - Fit for Time Constant')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.show()

plt.figure(figsize=(20,20))
i = 1
for name in keysFoilCount:
    plt.subplot(6,3,i)
    chan = np.linspace(left_endpt, right_endpt, right_endpt-left_endpt)
    count=dictFoilCount[name][left_endpt:right_endpt]
    
    plt.semilogy(chan2E(chan), dictFoilCount[name][left_endpt:right_endpt])
    plt.plot()
    plt.title(name)
    i = i+1
plt.tight_layout()
